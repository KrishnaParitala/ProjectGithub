# %%
import pandas as pd
data=pd.read_excel("Doctor_visits_analysis (1).xlsx")
data
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
data.shape
# Out:
# (5190, 13)

# %%
data.describe()
# Out:
#         Unnamed: 0       visits          age       income      illness  \
# count  5190.000000  5190.000000  5190.000000  5190.000000  5190.000000
# mean   2595.500000     0.301734     0.406385     0.583160     1.431985
# std    1498.368279     0.798134     0.204782     0.368907     1.384152
# min       1.000000     0.000000     0.190000     0.000000     0.000000
# 25%    1298.250000     0.000000     0.220000     0.250000     0.000000
# 50%    2595.500000     0.000000     0.320000     0.550000     1.000000
# 75%    3892.750000     0.000000     0.620000     0.900000     2.000000
# max    5190.000000     9.000000     0.720000     1.500000     5.000000
#
#            reduced       health
# count  5190.000000  5190.000000
# mean      0.861850     1.217534
# std       2.887628     2.124266
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     2.000000
# max      14.000000    12.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
data.head()
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %%
pd.isnull(data).sum()
# Out:
# Unnamed: 0    0
# visits        0
# gender        0
# age           0
# income        0
# illness       0
# reduced       0
# health        0
# private       0
# freepoor      0
# freerepat     0
# nchronic      0
# lchronic      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
data['income']=data['income']*10000
data['age']=data['age']*100
data
# Out:
#       Unnamed: 0  visits  gender   age   income  illness  reduced  health  \
# 0              1       1  female  19.0   5500.0        1        4       1
# 1              2       1  female  19.0   4500.0        1        2       1
# 2              3       1    male  19.0   9000.0        3        0       0
# 3              4       1    male  19.0   1500.0        1        0       0
# 4              5       1    male  19.0   4500.0        2        5       1
# ...          ...     ...     ...   ...      ...      ...      ...     ...
# 5185        5186       0  female  22.0   5500.0        0        0       0
# 5186        5187       0    male  27.0  13000.0        0        0       1
# 5187        5188       0  female  37.0   2500.0        1        0       1
# 5188        5189       0  female  52.0   6500.0        0        0       0
# 5189        5190       0    male  72.0   2500.0        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %% [markdown]
# #

# %% [markdown]
# # count and visualize the number of male and female affected by ill

# %%
ax=sn.countplot(x='gender',color='green',data=data)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Visualize and Analyze the Maximum,Minimum and median level of income

# %%
x=list(data.income)
plt.boxplot(x)
plt.show()

# %%
b1=plt.barh(data['age'],data['nchronic'],color="yellow")
b2=plt.barh(data['age'],data['lchronic'],color="red")
plt.legend([b1,b2],["nchron","Ichron"],title="health",loc="upper right")
plt.show()

# %% [markdown]
# # Visits the Doctor as Age Wise

# %%
plt.figure(figsize=(20,10))
ax=plt.bar(data['age'],data['visits'])
plt.xlabel("age")
plt.ylabel("visits")
plt.show()

# %% [markdown]
# # Count the Persons with respect to getting times of Illness

# %%
y=data['illness'].value_counts().plot(kind='bar')
for bars in y.containers:
    y.bar_label(bars)

# %%
data.plot(kind='scatter',x='illness',y='income')
# Out:
# <AxesSubplot:xlabel='illness', ylabel='income'>

# %%
y1=data['illness'].plot(kind='hist')
for hist in y1.containers:
    y1.bar_label(hist)

# %%
data.groupby(['gender','income']).mean()
# Out:
#                  Unnamed: 0    visits        age   illness   reduced    health
# gender income
# female 0.0      2426.540000  0.360000  35.700000  1.240000  0.980000  1.840000
#        100.0    2239.631579  0.473684  32.263158  1.526316  0.157895  1.578947
#        600.0    2592.317073  0.195122  36.487805  1.317073  0.536585  2.170732
#        1500.0   2284.234483  0.482759  43.434483  1.655172  0.613793  1.455172
#        2500.0   2373.679398  0.430556  62.040509  1.947917  1.210648  1.401620
#        3500.0   2342.854093  0.430605  51.921708  1.594306  1.231317  1.548043
#        4500.0   2300.757848  0.376682  38.291480  1.596413  0.878924  1.278027
#        5500.0   2276.589431  0.276423  35.337398  1.524390  1.028455  1.292683
#        6500.0   2371.798246  0.223684  33.241228  1.350877  0.815789  1.162281
#        7500.0   2373.316384  0.305085  34.610169  1.316384  0.694915  0.774011
#        9000.0   2503.238739  0.279279  33.765766  1.360360  0.617117  1.288288
# ...

# %%
data.groupby(['gender','income']).median()
# Out:
#                 Unnamed: 0  visits   age  illness  reduced  health
# gender income
# female 0.0          2197.5     0.0  22.0      1.0      0.0     0.0
#        100.0        1642.0     0.0  22.0      1.0      0.0     0.0
#        600.0        2630.0     0.0  27.0      1.0      0.0     1.0
#        1500.0       2293.0     0.0  42.0      1.0      0.0     0.0
#        2500.0       2378.5     0.0  67.0      2.0      0.0     0.0
#        3500.0       2312.0     0.0  62.0      1.0      0.0     0.0
#        4500.0       2474.0     0.0  22.0      1.0      0.0     0.0
#        5500.0       2246.0     0.0  22.0      1.0      0.0     0.0
#        6500.0       2100.0     0.0  22.0      1.0      0.0     0.0
#        7500.0       2022.0     0.0  27.0      1.0      0.0     0.0
#        9000.0       2402.0     0.0  27.0      1.0      0.0     0.0
#        11000.0      1968.5     0.0  27.0      1.0      0.0     0.0
#        13000.0      1862.0     0.0  37.0      1.0      0.0     0.0
# ...

# %%
s=data.groupby(['illness','gender']).plot(kind='bar')
# Out:
# Error in callback <function flush_figures at 0x000001F782CCCC10> (for post_execute):
# KeyboardInterrupt

# %% [markdown]
# # find out the correlation between variables in the given dataset correlation between different variables

# %%
plt.figure(figsize=(10,10))
sn.heatmap(data.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # visualize the percentage of people getting govt health insurance due to low income,due to old age and also the percentage of people having private health insurance

# %%
label=['yes','no']
y=data[data['freepoor']=='yes']
n=data[data['freepoor']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt health insurance due to low income")
plt.show()
y=data[data['private']=='yes']
n=data[data['private']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people having private health insurance")
plt.show()
y=data[data['freerepat']=='yes']
n=data[data['freerepat']=='no']
x=[y.shape[0],n.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt health insurance due to old age,disability or veteran states")
plt.show()

# %%
db=data.groupby('gender')['illness'].sum().to_frame().reset_index()
plt.barh(db['gender'],db['illness'],color=['''lightseagreen'])
# Out:
#   Input In [23]
#     plt.barh(db['gender'],db['illness'],color=['''lightseagreen'])
#                                                                   ^
# SyntaxError: EOF while scanning triple-quoted string literal
